# %% [markdown]
# # Criando dataset para treinamento de rede neural

# %%
# from Scripts.data import plot_and_resize_candles as ar
from Scripts.data import get_trend_and_image as getData
from Scripts.itensObject import itensIterator 
from Scripts.saveData import generateJson,saveImage
trends = list()
for name , archive in enumerate(itensIterator):
    image_resized, trend = getData(archive)
    saveImage(image_resized,name)
    trends.append({name:trend})
